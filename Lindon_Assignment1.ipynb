# %%
import tensorflow as tf

x_data = [14, 20, 22, 30, 34, 35, 40, 41, 45, 46, 52]
y_data = [78, 84, 84, 88, 78, 87, 92, 108, 98, 87, 80]

#placeholders for a tensor that will be alaways fed through feed_dict
x = tf.placeholder(tf.float32)
y = tf.placeholder(tf.float32)

w1 = tf.Variable(tf.random_normal([1]), name='weight1')
w2 = tf.Variable(tf.random_normal([1]), name='weight2')
w3 = tf.Variable(tf.random_normal([1]), name='weight3')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = w1 * x + w2 + w3 + b

#cost function
cost = tf.reduce_mean(tf.square(hypothesis - y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.00001) #1e-5
train=optimizer.minimize(cost)

#Launch the graph in a session
sess = tf.Session()

#Initialize global variables
sess.run(tf.global_variables_initializer())

for step in range(3001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train], 
                                  feed_dict={x:x_data, y:y_data})
    if step % 30==0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  14102.887
# Prediction:
#  [-13.182014 -18.16192  -19.821888 -26.461761 -29.7817   -30.611683
#  -34.761604 -35.591587 -38.911526 -39.74151  -44.721413]
# 30 Cost:  3371.825
# Prediction:
#  [11.581229 17.149008 19.004932 26.428637 30.14049  31.06845  35.708267
#  36.636227 40.34808  41.276043 46.843822]
# 60 Cost:  1215.7216
# Prediction:
#  [22.685608 32.97991  36.411346 50.137085 56.999954 58.71567  67.294266
#  69.00998  75.87285  77.58857  87.88287 ]
# 90 Cost:  782.37555
# Prediction:
#  [ 27.667738  40.079384  44.2166    60.765453  69.03989   71.10849
#   81.45153   83.520134  91.79456   93.863174 106.27481 ]
# 120 Cost:  695.141
# Prediction:
#  [ 29.905727  43.265205  47.718365  65.531006  74.43732   76.6639
#   87.7968    90.02338   98.929695 101.15628  114.515755]
# 150 Cost:  677.4421
# Prediction:
#  [ 30.913733  44.696846  49.291218  67.6687    76.85745   79.15463
#   90.640564  92.93775  102.126495 104.42368  118.2068  ]
# 180 Cost:  673.7135
# Prediction:
# ...
